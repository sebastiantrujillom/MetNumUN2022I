# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p =  x**10 - 58*x**9 + 1311*x**8 - 15144*x**7 + 94539*x**6 - 280578*x**5 - 18631*x**4 + 2741044*x**3 - 8008740*x**2 + 9477936*x - 3991680

p, r = div(p,  x-1)

print(p)
print(r)

p, r = div(p,  x-2)

print(p)
print(r)

p, r = div(p,  x-3)

print(p)
print(r)

p, r = div(p,  x-4)

print(p)
print(r)
p, r = div(p,  x-5)

print(p)
print(r)
p, r = div(p,  x-9)

print(p)
print(r)
p, r = div(p,  x+3)

print(p)
print(r)

p, r = div(p,  x-8)

print(p)
print(r)

p, r = div(p,  x-22)

print(p)
print(r)

p, r = div(p,  x-7)

print(p)
print(r)
# Out:
# x**9 - 57*x**8 + 1254*x**7 - 13890*x**6 + 80649*x**5 - 199929*x**4 - 218560*x**3 + 2522484*x**2 - 5486256*x + 3991680
# 0
# x**8 - 55*x**7 + 1144*x**6 - 11602*x**5 + 57445*x**4 - 85039*x**3 - 388638*x**2 + 1745208*x - 1995840
# 0
# x**7 - 52*x**6 + 988*x**5 - 8638*x**4 + 31531*x**3 + 9554*x**2 - 359976*x + 665280
# 0
# x**6 - 48*x**5 + 796*x**4 - 5454*x**3 + 9715*x**2 + 48414*x - 166320
# 0
# x**5 - 43*x**4 + 581*x**3 - 2549*x**2 - 3030*x + 33264
# 0
# x**4 - 34*x**3 + 275*x**2 - 74*x - 3696
# 0
# x**3 - 37*x**2 + 386*x - 1232
# 0
# x**2 - 29*x + 154
# 0
# x - 7
# 0
# 1
# 0

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p = x**10 - 58*x**9 + 1311*x**8 - 15144*x**7 + 94539*x**6 - 280578*x**5 - 18631*x**4 + 2741044*x**3 - 8008740*x**2 + 9477936*x - 3991680

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor (x**10 - 58*x**9 + 1311*x**8 - 15144*x**7 + 94539*x**6 - 280578*x**5 - 18631*x**4 + 2741044*x**3 - 8008740*x**2 + 9477936*x - 3991680)
# Out:
# (x - 22)*(x - 9)*(x - 8)*(x - 7)*(x - 5)*(x - 4)*(x - 3)*(x - 2)*(x - 1)*(x + 3)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**10 - 58*x**9 + 1311*x**8 - 15144*x**7 + 94539*x**6 - 280578*x**5 - 18631*x**4 + 2741044*x**3 - 8008740*x**2 + 9477936*x - 3991680), x)
# Out:
# /usr/local/lib/python3.7/dist-packages/sympy/core/relational.py:496: SymPyDeprecationWarning:
#
# Eq(expr) with rhs default to 0 has been deprecated since SymPy 1.5.
# Use Eq(expr, 0) instead. See
# https://github.com/sympy/sympy/issues/16587 for more info.
#
#   deprecated_since_version="1.5"
# FiniteSet(-3, 1, 2, 3, 4, 5, 7, 8, 9, 22)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi
x = Symbol('x')
solveset(Eq(x**2 - (sqrt(7)+pi)*x + (sqrt(7)*pi) , 0), x)
# Out:
# FiniteSet(pi, sqrt(7))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(5*x**5 - 22*x**4  - 4*x**3 + 8*x**2 - 10*x - 4,domain='GF(2)')
# Out:
# x**5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import symbols, I, N, pi,sqrt, expand
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)  
x = x1 + I*sqrt(x2)
y = y1 + I*sqrt(y2)
z = I*z1

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))

w=N(1/(pi + I), 20)
print('w=',w)
# Out:
# I*z1*(x1 + I*sqrt(x2))*(y1 + I*sqrt(y2))
# I*x1*y1*z1 - x1*sqrt(y2)*z1 - sqrt(x2)*y1*z1 - I*sqrt(x2)*sqrt(y2)*z1
# I*x1*y1*z1 - x1*sqrt(y2)*z1 - sqrt(x2)*y1*z1 - I*sqrt(x2)*sqrt(y2)*z1
# I*x1*y1*z1 - x1*sqrt(y2)*z1 - sqrt(x2)*y1*z1 - I*sqrt(x2)*sqrt(y2)*z1
# w= 0.28902548222223624241 - 0.091999668350375232456*I

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin, E
x = Symbol('x')
integrate((x**2)*(E**3*x), x)
# Out:
# x**4*exp(3)/4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, cos
x = Symbol('x')
integrate(x**2 * cos(x)**3, (x,2,6))
# Out:
# 310*sin(6)*cos(6)**2/9 - 32*sin(2)**3/27 + 608*sin(6)**3/27 - 22*sin(2)*cos(2)**2/9 - 28*cos(2)**3/9 + 8*sin(6)**2*cos(6) - 8*sin(2)**2*cos(2)/3 + 28*cos(6)**3/3

# %%
from sympy import Symbol, integrate, cos, N
x = Symbol('x')
N(integrate(x**2 * cos(x)**3, (x,2,6)))
# Out:
# -0.636738703563946
